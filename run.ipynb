# %%
# !python /home/arnav/CVproj/D4/test.py --model 1 --checkpoints /home/arnav/CVproj/D4/checkpoints/reside6k_test
# Out:
# Using cache found in /home/arnav/.cache/torch/hub/rwightman_gen-efficientnet-pytorch_master
# Using cache found in /home/arnav/.cache/torch/hub/rwightman_gen-efficientnet-pytorch_master
# ['/home/arnav/CVproj/RESIDE-6K/test/GT/0001_0.8_0.2.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0002_0.8_0.08.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0003_0.8_0.2.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0004_0.9_0.12.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0006_0.85_0.08.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0007_0.9_0.16.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0009_0.8_0.16.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0010_0.95_0.16.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0011_0.95_0.16.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0014_0.8_0.12.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0016_0.8_0.08.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0017_0.9_0.08.jpg'
#  '/home/arnav/CVproj/RESIDE-6K/test/GT/0018_0.9_0.2.jpg'
# ...

# %% [markdown]
# total PSNR for reside-6k test set excluding images starting with '14' = 21.493

# %% [markdown]
# FFA Net ots

# %%
# !cd FFA-Net/
# !python /home/arnav/CVproj/FFA-Net/net/test.py --task='ots' --test_imgs='test_imgs'
# Out:
# pred_dir: /home/arnav/CVproj/pred_FFA_ots/
#  0197_0.8_0.16.jpgFigure(640x480)
#  1438_2.pngFigure(640x480)
#  0108_0.8_0.16.jpgFigure(640x480)
#  1429_2.pngFigure(640x480)
#  0055_0.85_0.12.jpgFigure(640x480)
#  1869_1_0.2.jpgFigure(640x480)
#  0357_0.95_0.12.jpgFigure(640x480)
#  1411_2.pngFigure(640x480)
#  1431_1.pngFigure(640x480)
#  1434_8.pngFigure(640x480)
#  1425_6.pngFigure(640x480)
#  0244_0.9_0.12.jpgFigure(640x480)
#  1757_0.85_0.16.jpgFigure(640x480)
#  1834_1_0.08.jpgFigure(640x480)
#  1876_1_0.16.jpgFigure(640x480)
#  0223_0.95_0.16.jpgFigure(640x480)
#  1422_1.pngFigure(640x480)
#  1730_0.85_0.08.jpgFigure(640x480)
#  1437_8.pngFigure(640x480)
#  0108_1_0.2.jpgFigure(640x480)
#  1417_8.pngFigure(640x480)
#  1447_1.pngFigure(640x480)
#  1419_8.pngFigure(640x480)
#  0029_0.85_0.08.jpgFigure(640x480)
#  1956_0.8_0.12.jpgFigure(640x480)
#  1416_1.pngFigure(640x480)
#  1436_3.pngFigure(640x480)
#  0081_0.8_0.2.jpgFigure(640x480)
#  0145_0.8_0.12.jpgFigure(640x480)
# ...

# %%
# !cd FFA-Net/
# !python /home/arnav/CVproj/FFA-Net/net/test.py --task='its' --test_imgs='test_imgs'
# Out:
# pred_dir: /home/arnav/CVproj/pred_FFA_its/
#  0197_0.8_0.16.jpgFigure(640x480)
#  1438_2.pngFigure(640x480)
#  0108_0.8_0.16.jpgFigure(640x480)
#  1429_2.pngFigure(640x480)
#  0055_0.85_0.12.jpgFigure(640x480)
#  1869_1_0.2.jpgFigure(640x480)
#  0357_0.95_0.12.jpgFigure(640x480)
#  1411_2.pngFigure(640x480)
#  1431_1.pngFigure(640x480)
#  1434_8.pngFigure(640x480)
#  1425_6.pngFigure(640x480)
#  0244_0.9_0.12.jpgFigure(640x480)
#  1757_0.85_0.16.jpgFigure(640x480)
#  1834_1_0.08.jpgFigure(640x480)
#  1876_1_0.16.jpgFigure(640x480)
#  0223_0.95_0.16.jpgFigure(640x480)
#  1422_1.pngFigure(640x480)
#  1730_0.85_0.08.jpgFigure(640x480)
#  1437_8.pngFigure(640x480)
#  0108_1_0.2.jpgFigure(640x480)
#  1417_8.pngFigure(640x480)
#  1447_1.pngFigure(640x480)
#  1419_8.pngFigure(640x480)
#  0029_0.85_0.08.jpgFigure(640x480)
#  1956_0.8_0.12.jpgFigure(640x480)
#  1416_1.pngFigure(640x480)
#  1436_3.pngFigure(640x480)
#  0081_0.8_0.2.jpgFigure(640x480)
#  0145_0.8_0.12.jpgFigure(640x480)
# ...
